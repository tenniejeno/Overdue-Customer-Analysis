# %%
import pandas as pd

# %%
dataset = pd.read_csv("dataset.csv")

# %%
dataset
# Out:
#                          customer_id  is_pass  is_loan   apply_dt   disbr_dt  \
# 0      L1022001117904167299943301120        1        1  11/1/2018  13/1/2018
# 1      L1022001307911135269315870720        0        0  30/1/2018        NaN
# 2      L1022001297910884869316739072        0        0  29/1/2018        NaN
# 3      L1022001207907516176826302464        0        0  20/1/2018        NaN
# 4      L1022001147905381470621990912        1        1  14/1/2018  20/1/2018
# ...                              ...      ...      ...        ...        ...
# 34486  L1022001017900559016839675904        1        1   1/1/2018   3/1/2018
# 34487  L1022001317911322620012986368        0        0  31/1/2018        NaN
# 34488  L1022001217907835032476254208        0        0  21/1/2018        NaN
# 34489  L1022001307911207327924158464        0        0  30/1/2018        NaN
# 34490  L1022001247908797001404448768        0        0  24/1/2018        NaN
#
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34491 entries, 0 to 34490
# Data columns (total 46 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       34491 non-null  object
#  1   is_pass           34491 non-null  int64
#  2   is_loan           34491 non-null  int64
#  3   apply_dt          34491 non-null  object
#  4   disbr_dt          6442 non-null   object
#  5   is_overdue        6442 non-null   float64
#  6   age               34467 non-null  float64
#  7   gender_v          34491 non-null  object
#  8   education_v       34491 non-null  object
#  9   marriage_v        34491 non-null  object
#  10  live_state        34491 non-null  int64
#  11  live_county       34491 non-null  int64
#  12  residence_type_v  34491 non-null  object
#  13  employ_stat_v     34491 non-null  object
#  14  occupation_v      34490 non-null  object
#  15  mon_salary_v      34491 non-null  object
# ...

# %%
dataset.describe()
# Out:
#             is_pass       is_loan   is_overdue           age    live_state  \
# count  34491.000000  34491.000000  6442.000000  3.446700e+04  3.449100e+04
# mean       0.205068      0.186773     0.188140  3.208453e+02  1.019327e+07
# std        0.403757      0.389735     0.390855  5.386379e+04  3.034642e+05
# min        0.000000      0.000000     0.000000 -9.900000e+01  1.009000e+06
# 25%        0.000000      0.000000     0.000000  2.600000e+01  1.011000e+07
# 50%        0.000000      0.000000     0.000000  3.000000e+01  1.020000e+07
# 75%        0.000000      0.000000     0.000000  3.500000e+01  1.030000e+07
# max        1.000000      1.000000     1.000000  9.999999e+06  1.035000e+07
#
#         live_county    work_state   work_county  cont_list_no      ap_pd24h  \
# count  3.449100e+04  3.449100e+04  3.449100e+04  34467.000000  34467.000000
# mean   1.019328e+07  1.019056e+07  1.019058e+07    397.355674     -0.398265
# ...

# %% [markdown]
# ### 处理重复值

# %%
print(dataset.duplicated().sum())
# Out:
# 999

# %%
dataset.drop_duplicates(inplace=True)

# %%
# 重置索引
dataset.index = range(dataset.shape[0])
dataset
# Out:
#                          customer_id  is_pass  is_loan   apply_dt   disbr_dt  \
# 0      L1022001117904167299943301120        1        1  11/1/2018  13/1/2018
# 1      L1022001307911135269315870720        0        0  30/1/2018        NaN
# 2      L1022001297910884869316739072        0        0  29/1/2018        NaN
# 3      L1022001207907516176826302464        0        0  20/1/2018        NaN
# 4      L1022001147905381470621990912        1        1  14/1/2018  20/1/2018
# ...                              ...      ...      ...        ...        ...
# 33487  L1022001227908314125491699712        0        0   2/1/2018        NaN
# 33488  L1022001197907283701941207040        1        1   7/1/2018   8/1/2018
# 33489  L1022001217907971852023300096        0        0   4/1/2018        NaN
# 33490  L1022001317911335140262084608        1        1  30/1/2018  31/1/2018
# 33491  L1022001317911418006547398656        0        0  20/1/2018        NaN
#
# ...

# %% [markdown]
# ### 处理缺失值

# %%
#统计空值个数
dataset.isnull().sum()
# Out:
# customer_id             0
# is_pass                 0
# is_loan                 0
# apply_dt                0
# disbr_dt            27254
# is_overdue          27254
# age                    23
# gender_v                0
# education_v             0
# marriage_v              0
# live_state              0
# live_county             0
# residence_type_v        0
# employ_stat_v           0
# occupation_v            1
# mon_salary_v            0
# work_state              0
# work_county             0
# system_version         41
# cont1_rel_v             0
# cont2_rel_v             0
# cont_list_no           23
# ap_pd24h               23
# ap_pd3d                23
# ap_pd30d               23
# ap_long3d              23
# ap_long30d             23
# ap_long90d             23
# ap_al                9306
# ap_pdal              9306
# ap_longal            9306
# ap_dd_1lo            9306
# ap_dd_lalo           9306
# ap_dd_1lo_1ap        9306
# ap_loanal            9306
# ...

# %%
#统计-99个数
dataset[dataset == -99].count()
# Out:
# customer_id             0
# is_pass                 0
# is_loan                 0
# apply_dt                0
# disbr_dt                0
# is_overdue              0
# age                    50
# gender_v                0
# education_v             0
# marriage_v              0
# live_state              0
# live_county             0
# residence_type_v        0
# employ_stat_v           0
# occupation_v            0
# mon_salary_v            0
# work_state              0
# work_county             0
# system_version          0
# cont1_rel_v             0
# cont2_rel_v             0
# cont_list_no            0
# ap_pd24h              364
# ap_pd3d               364
# ap_pd30d              364
# ap_long3d             364
# ap_long30d            364
# ap_long90d            364
# ap_al                 234
# ap_pdal               234
# ap_longal             234
# ap_dd_1lo            1570
# ap_dd_lalo           1570
# ap_dd_1lo_1ap        1570
# ap_loanal             234
# ...

# %% [markdown]
# 考虑到手机上安装的app统计信息与征信报告信息中为空值与-99的数据数量太大，后续数据清洗不考虑该部分

# %% [markdown]
# 根据上面的运行结果可知age列有23个空值，50个-99，根据性别与婚姻状态分类得到各类年龄的众数，并用该值替换年龄中的空值与-99

# %%
import numpy as np

# %%
#计算众数
dataset.groupby(['gender_v','marriage_v'])['age'].agg(lambda x: x.value_counts().index[0]).reset_index()
# Out:
#   gender_v marriage_v   age
# 0   Female   Divorced  33.0
# 1   Female    Married  30.0
# 2   Female     Single  23.0
# 3   Female    Widowed  40.0
# 4     Male   Divorced  38.0
# 5     Male    Married  32.0
# 6     Male     Single  25.0
# 7     Male    Widowed  42.0

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Female') & (dataset['marriage_v'] == 'Divorced'),'age'] = 33

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Female') & (dataset['marriage_v'] == 'Married'),'age'] = 30

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Female') & (dataset['marriage_v'] == 'Single'),'age'] = 23

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Female') & (dataset['marriage_v'] == 'Widowed'),'age'] = 40

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Male') & (dataset['marriage_v'] == 'Divorced'),'age'] = 38

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Male') & (dataset['marriage_v'] == 'Married'),'age'] = 32

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Male') & (dataset['marriage_v'] == 'Single'),'age'] = 25

# %%
dataset.loc[((dataset['age'].isnull()) | (dataset['age'] == -99)) & (dataset['gender_v'] == 'Male') & (dataset['marriage_v'] == 'Widowed'),'age'] = 42

# %%
#用职业列的众数填补该列空值
dataset.occupation_v.fillna(dataset.occupation_v.mode()[0],inplace = True)

# %%
#用手机系统版本列的众数填补该列空值
dataset.system_version.fillna(dataset.system_version.mode()[0],inplace = True)

# %%
#用通讯录联系人数量的中位数填补该列空值
dataset.cont_list_no.fillna(dataset.cont_list_no.median(),inplace = True)

# %%
dataset.describe()
# Out:
#             is_pass       is_loan   is_overdue           age    live_state  \
# count  33492.000000  33492.000000  6238.000000  3.349200e+04  3.349200e+04
# mean       0.204616      0.186253     0.188682  3.294575e+02  1.019345e+07
# std        0.403427      0.389317     0.391287  5.464219e+04  2.991597e+05
# min        0.000000      0.000000     0.000000  0.000000e+00  1.009000e+06
# 25%        0.000000      0.000000     0.000000  2.600000e+01  1.011000e+07
# 50%        0.000000      0.000000     0.000000  3.000000e+01  1.020000e+07
# 75%        0.000000      0.000000     0.000000  3.500000e+01  1.030000e+07
# max        1.000000      1.000000     1.000000  9.999999e+06  1.035000e+07
#
#         live_county    work_state   work_county  cont_list_no      ap_pd24h  \
# count  3.349200e+04  3.349200e+04  3.349200e+04  33492.000000  33469.000000
# mean   1.019347e+07  1.019092e+07  1.019093e+07    397.525469     -0.408736
# ...

# %% [markdown]
# ### 异常值处理

# %%
#检查贷款审批与发放贷款是否有异常
dataset.loc[(dataset['is_pass']==0) & (dataset['is_loan']==1)]
# Out:
# Empty DataFrame
# Columns: [customer_id, is_pass, is_loan, apply_dt, disbr_dt, is_overdue, age, gender_v, education_v, marriage_v, live_state, live_county, residence_type_v, employ_stat_v, occupation_v, mon_salary_v, work_state, work_county, system_version, cont1_rel_v, cont2_rel_v, cont_list_no, ap_pd24h, ap_pd3d, ap_pd30d, ap_long3d, ap_long30d, ap_long90d, ap_al, ap_pdal, ap_longal, ap_dd_1lo, ap_dd_lalo, ap_dd_1lo_1ap, ap_loanal, cd_score, cd_open_acct, cd_ovdu_acct, cd_ovdu_amt, cd_ovdu_tms, cd_max_ovdudys, cd_tot_bal, cd_enq_tot30d, cd_enq_tot60d, cd_enq_org30d, cd_enq_org60d]
# Index: []
#
# [0 rows x 46 columns]

# %%
#转换时间格式
dataset['apply_dt'] = pd.to_datetime(dataset.apply_dt,format='%d/%m/%Y')
dataset['disbr_dt'] = pd.to_datetime(dataset.disbr_dt,format='%d/%m/%Y')

# %%
#检查贷款申请与发放时间是否有异常
dataset[dataset['apply_dt'] > dataset['disbr_dt']]
# Out:
# Empty DataFrame
# Columns: [customer_id, is_pass, is_loan, apply_dt, disbr_dt, is_overdue, age, gender_v, education_v, marriage_v, live_state, live_county, residence_type_v, employ_stat_v, occupation_v, mon_salary_v, work_state, work_county, system_version, cont1_rel_v, cont2_rel_v, cont_list_no, ap_pd24h, ap_pd3d, ap_pd30d, ap_long3d, ap_long30d, ap_long90d, ap_al, ap_pdal, ap_longal, ap_dd_1lo, ap_dd_lalo, ap_dd_1lo_1ap, ap_loanal, cd_score, cd_open_acct, cd_ovdu_acct, cd_ovdu_amt, cd_ovdu_tms, cd_max_ovdudys, cd_tot_bal, cd_enq_tot30d, cd_enq_tot60d, cd_enq_org30d, cd_enq_org60d]
# Index: []
#
# [0 rows x 46 columns]

# %%
#处理年龄列的异常值
dataset.sort_values(by = 'age',ascending = False).head(10)
# Out:
#                          customer_id  is_pass  is_loan   apply_dt   disbr_dt  \
# 2244   L1022001227908323345800822784        1        1 2018-01-23 2018-01-28
# 1387   L1022001017900640083162365952        1        1 2018-01-26 2018-01-27
# 10     L1022001207907516176973103104        0        0 2018-01-20        NaT
# 47     L1022001237908604270493237248        0        0 2018-01-23        NaT
# 94     L1022001297910861476810915840        0        0 2018-01-17        NaT
# 28     L1022001267909748343237181440        0        0 2018-01-26        NaT
# 706    L1022001207907438876638248960        1        1 2018-01-23 2018-01-27
# 27148  L1022001197907149993347186688        0        0 2018-01-19        NaT
# 24289  L1022001037901253817093652480        0        0 2018-01-25        NaT
# 3623   L1022001207907582822907576320        0        0 2018-01-28        NaT
#
#        is_overdue        age gender_v              education_v marriage_v  \
# ...

# %%
dataset.loc[dataset['age'] > 120,'age'] = 80

# %% [markdown]
# ## 预测逾期模型

# %%
##  基础函数库
import numpy as np 
import pandas as pd

## 绘图函数库
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %%
#筛选出获得贷款的用户
data_is_loan = dataset[dataset['is_loan'] == 1]
data_is_loan = data_is_loan.dropna(axis = 0)

# %%
data_is_loan.index = range(data_is_loan.shape[0])

# %%
data_is_loan
# Out:
#                         customer_id  is_pass  is_loan   apply_dt   disbr_dt  \
# 0     L1022001267909780587997757440        1        1 2018-01-26 2018-01-27
# 1     L1022001317911582115926573056        1        1 2018-01-31 2018-02-01
# 2     L1022001227908285574264586240        1        1 2018-01-22 2018-01-30
# 3     L1022001297910838214240436224        1        1 2018-01-29 2018-01-30
# 4     L1022001267909780769539817472        1        1 2018-01-26 2018-01-27
# ...                             ...      ...      ...        ...        ...
# 3486  L1022001247908897789749428224        1        1 2018-01-26 2018-01-27
# 3487  L1022001227908323130440089600        1        1 2018-01-23 2018-01-29
# 3488  L1022001247908957239197761536        1        1 2018-01-31 2018-01-31
# 3489  L1022001117904275297277640704        1        1 2018-01-24 2018-01-27
# 3490  L1022001317911335140262084608        1        1 2018-01-30 2018-01-31
#
# ...

# %%
#得到数据特征和标签
data_features = data_is_loan.drop(['customer_id','is_pass','is_loan','apply_dt','disbr_dt'],axis=1)

# %%
data_features.head(10)
# Out:
#    is_overdue   age gender_v              education_v marriage_v  live_state  \
# 0         1.0  27.0     Male                     12th    Married    10280000
# 1         0.0  27.0     Male                     12th     Single    10200000
# 2         0.0  27.0     Male  Masters/Post-Graduation    Married    10310000
# 3         0.0  31.0     Male               Below 10th    Married    10340000
# 4         0.0  33.0     Male                     10th    Married    10080000
# 5         0.0  31.0     Male       Graduation/Diploma    Married    10010000
# 6         1.0  26.0     Male                     10th     Single    10150000
# 7         0.0  32.0     Male       Graduation/Diploma    Married    10300000
# 8         1.0  23.0     Male                     12th     Single    10150000
# 9         0.0  29.0     Male  Masters/Post-Graduation    Married    10100000
#
#    live_county residence_type_v  employ_stat_v  \
# 0     10280018               PG  Self-employed
# ...

# %%
#gender_v转数字
size_mapping = {'Male':0, 'Female':1}
data_features['gender_v'] = data_features['gender_v'].map(size_mapping)

# %%
#逾期比例的计算与排序在MySQL实现

# %%
#education_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Doctorate/PhD':1, 'Masters/Post-Graduation':2, 'Graduation/Diploma':3,
                '10th':4,'Below 10th':5,'12th':6}
data_features['education_v'] = data_features['education_v'].map(size_mapping)

# %%
#marriage_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Married':1, 'Single':2, 'Divorced':3,'Widowed':4}
data_features['marriage_v'] = data_features['marriage_v'].map(size_mapping)

# %%
#live_state随机赋值
class_encoder = LabelEncoder()
data_features['live_state'] = class_encoder.fit_transform(data_features['live_state'].values)

# %%
#live_county随机赋值
class_encoder = LabelEncoder()
data_features['live_county'] = class_encoder.fit_transform(data_features['live_county'].values)

# %%
#residence_type_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Rent':1, 'Own a house':2, 'Other':3,
                'PG':4,'Company distribution':5}
data_features['residence_type_v'] = data_features['residence_type_v'].map(size_mapping)

# %%
#employ_stat_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Unemployed':1, 'Salaried':2, 'Self-employed':3,
                'Student':4,'Retired':5}
data_features['employ_stat_v'] = data_features['employ_stat_v'].map(size_mapping)

# %%
#occupation_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Elementary occupations':1, 'Technicians and associate prefessionals':2, 
                'Professional':3,'Plant and machine operators, and assemblers':4,
                'Managers':5, 'Armed forces occupations':6, 'Service and sales workers':7, 
               'Craft and related trades workers':8, 'Clerical support workers':9,
               'Skilled agricultural, forestry and fishery workers':10}
data_features['occupation_v'] = data_features['occupation_v'].map(size_mapping)

# %%
#mon_salary_v从小到大赋值1，2，3。。。
size_mapping = {'<10,000':1, '10,000-15,000':2, '15,000-20,000':3,
                '20,000-30,000':4,'30,000-50,000':5, '50,000-100,000':6,
               '100,000-200,000':7,'200,000-500,000':8,'>=500,000':9}
data_features['mon_salary_v'] = data_features['mon_salary_v'].map(size_mapping)

# %%
#work_state随机赋值
class_encoder = LabelEncoder()
data_features['work_state'] = class_encoder.fit_transform(data_features['work_state'].values)

# %%
#work_county随机赋值
class_encoder = LabelEncoder()
data_features['work_county'] = class_encoder.fit_transform(data_features['work_county'].values)

# %%
#system_version逾期比例从小到大赋值0,1，2，3。。。
size_mapping = {'4.4.4':0,'7.0.1':0,'4.4.2':1, '5':1,'10':2, '6':3,
                '9':4,'6.0.1':5, '7.1.2':6,'5.0.2':7,'8.1.0':8,'7.1.1':9,'5.1.1':10,
               '7':11,'8.0.0':12,'5.1':13}
data_features['system_version'] = data_features['system_version'].map(size_mapping)

# %%
#cont1_rel_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Sibling':1, 'Friend':2, 'Spouse':3,
                'Colleague':4,'Mother':5}
data_features['cont1_rel_v'] = data_features['cont1_rel_v'].map(size_mapping)

# %%
#cont2_rel_v逾期比例从小到大赋值1，2，3。。。
size_mapping = {'Mother':1, 'Spouse':2, 'Father':3,}
data_features['cont2_rel_v'] = data_features['cont2_rel_v'].map(size_mapping)

# %%
data_features = data_features.astype(int)

# %%
data_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3491 entries, 0 to 3490
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   is_overdue        3491 non-null   int32
#  1   age               3491 non-null   int32
#  2   gender_v          3491 non-null   int32
#  3   education_v       3491 non-null   int32
#  4   marriage_v        3491 non-null   int32
#  5   live_state        3491 non-null   int32
#  6   live_county       3491 non-null   int32
#  7   residence_type_v  3491 non-null   int32
#  8   employ_stat_v     3491 non-null   int32
#  9   occupation_v      3491 non-null   int32
#  10  mon_salary_v      3491 non-null   int32
#  11  work_state        3491 non-null   int32
#  12  work_county       3491 non-null   int32
#  13  system_version    3491 non-null   int32
#  14  cont1_rel_v       3491 non-null   int32
#  15  cont2_rel_v       3491 non-null   int32
# ...

# %%
#删去含有-99异常值的行
data_features = data_features.drop(data_features[data_features['ap_pd24h'] == -99].index)
data_features = data_features.drop(data_features[data_features['ap_al'] == -99].index)
data_features = data_features.drop(data_features[data_features['ap_dd_1lo'] == -99].index)
data_features = data_features.drop(data_features[data_features['ap_loanal'] == -99].index)
data_features = data_features.drop(data_features[data_features['cd_max_ovdudys'] == -99].index)
data_features = data_features.drop(data_features[data_features['cd_enq_tot30d'] == -99].index)

# %%
data_features.index = range(data_features.shape[0])

# %%
data_target=np.array(data_features['is_overdue']) #得到数据对应的标签

# %%
data_features = data_features.drop(['is_overdue'],axis=1)

# %%
## 利用value_counts函数查看每个类别数量
pd.Series(data_target).value_counts()
# Out:
# 0    502
# 1    103
# dtype: int64

# %%
## 对于特征进行一些统计描述
data_features.describe()
# Out:
#               age    gender_v  education_v  marriage_v  live_state  \
# count  605.000000  605.000000   605.000000  605.000000  605.000000
# mean    31.183471    0.085950     3.788430    1.398347   15.699174
# std      6.025420    0.280523     1.350079    0.499997    8.694717
# min     20.000000    0.000000     1.000000    1.000000    0.000000
# 25%     27.000000    0.000000     3.000000    1.000000    9.000000
# 50%     30.000000    0.000000     3.000000    1.000000   16.000000
# 75%     34.000000    0.000000     5.000000    2.000000   24.000000
# max     80.000000    1.000000     6.000000    4.000000   29.000000
#
#        live_county  residence_type_v  employ_stat_v  occupation_v  \
# count   605.000000        605.000000     605.000000    605.000000
# mean    210.492562          1.892562       2.319008      5.062810
# std     130.193356          0.695321       0.513770      2.076203
# min       0.000000          1.000000       1.000000      1.000000
# ...

# %%
## 合并标签和特征信息
data_all = data_features.copy() ##进行浅拷贝，防止对于原始数据的修改
data_all['target'] = data_target

# %%
label=pd.Series(data_target)

# %% [markdown]
# 特征与标签组合的散点可视化
# sns.pairplot(data=data_all,diag_kind='hist', hue= 'target')
# plt.show()

# %%
for col in data_features.columns:
    sns.boxplot(x='target', y=col, saturation=0.5,palette='pastel', data=data_all)
    plt.title(col)
    plt.show()

# %% [markdown]
# ### 筛选特征

# %%
# 计算 IV 函数
def cal_iv(x, y, n_bins=6, null_value=np.nan,):
   
    # 剔除空值
    x = x[x != null_value]
    
    # 若 x 只有一个值，返回 0
    if len(x.unique()) == 1 or len(x) != len(y):
        return 0
    
    if x.dtype == np.number:
        # 数值型变量
        if x.nunique() > n_bins:
            # 若 nunique 大于箱数，进行分箱
            x = pd.qcut(x, q=n_bins, duplicates='drop')
                
    # 计算IV
    groups = x.groupby([x, list(y)]).size().unstack().fillna(0)
    t0, t1 = y.value_counts().index
    groups = groups / groups.sum()
    not_zero_index = (groups[t0] > 0) & (groups[t1] > 0)
    groups['iv_i'] = (groups[t0] - groups[t1]) * np.log(groups[t0] / groups[t1])
    iv = sum(groups['iv_i'])
 
    return iv

# %%
# 统计每个特征对应的 iv 值
fea_iv = data_features.apply(lambda x: cal_iv(x, label), axis=0).sort_values(ascending=False)

 
# 筛选 IV > 0.05 的特征
imp_fea_iv = fea_iv[fea_iv > 0.05].index
imp_fea_iv
# Out:
# C:\Users\24670\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\24670\Anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Index(['age', 'ap_loanal', 'ap_al', 'ap_pdal', 'ap_longal', 'ap_dd_1lo',
#        'ap_dd_lalo', 'ap_dd_1lo_1ap', 'cd_score', 'ap_pd30d', 'cd_ovdu_amt',
#        'cd_ovdu_tms', 'cd_tot_bal', 'cd_enq_tot30d', 'cd_enq_tot60d',
#        'cd_enq_org30d', 'ap_long3d', 'ap_long30d', 'occupation_v',
#        'work_state', 'education_v', 'marriage_v', 'live_state', 'live_county',
#        'residence_type_v', 'employ_stat_v', 'mon_salary_v', 'cd_enq_org60d',
#        'work_county', 'system_version', 'cont_list_no', 'cd_open_acct',
# ...

# %%
data_all
# Out:
#      age  gender_v  education_v  marriage_v  live_state  live_county  \
# 0     35         0            3           1           0            4
# 1     30         0            6           1          10          110
# 2     27         0            6           1          20          269
# 3     39         0            4           1          22          311
# 4     43         0            5           1          24          316
# ..   ...       ...          ...         ...         ...          ...
# 600   30         1            3           1          29          442
# 601   34         0            6           1          24          322
# 602   38         0            4           1          10           98
# 603   37         0            4           1          13          139
# 604   24         0            6           2          13          142
#
#      residence_type_v  employ_stat_v  occupation_v  mon_salary_v  ...  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# 设定参数从10到1000
param = {'n_estimators': list(range(10, 1001, 50))}
g = GridSearchCV(estimator = RandomForestClassifier(random_state = 2020), param_grid = param, cv = 5)
g.fit(data_all, label)
g.best_estimator_
# Out:
# C:\Users\24670\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_folds = np.zeros(n_samples, dtype=np.int)
# ...

# %%
#n_estimators的最佳取值为60
param = {'n_estimators': list(range(10, 110, 10))}
g = GridSearchCV(estimator = RandomForestClassifier(random_state = 2020), param_grid = param, cv = 5)
g.fit(data_all, label)
g.best_estimator_
# Out:
# C:\Users\24670\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_folds = np.zeros(n_samples, dtype=np.int)
# ...

# %%
rf = g.best_estimator_ 
rf_impc = pd.Series(rf.feature_importances_, index=data_all.columns).sort_values(ascending=False)

# %%
del rf_impc['target']

# %%
# 筛选重要性前十的特征
imp_fea_rf = rf_impc.index[:10]

# %%
# 合并特征并筛选出有用特征
imp_fea = list(set(imp_fea_iv) & set(imp_fea_rf))
data_features_1 = data_features[imp_fea]

# %% [markdown]
# ### 利用逻辑回归模型在二分类上进行训练和预测

# %%
## 为了正确评估模型性能，将数据划分为训练集和测试集，并在训练集上训练模型，在测试集上验证模型性能。
from sklearn.model_selection import train_test_split

## 测试集大小为20%， 80%/20%分
x_train, x_test, y_train, y_test = train_test_split(data_features_1, data_target, test_size = 0.2, random_state = 2022)

# %%
from sklearn import preprocessing

# %%
#数据标准化
values = x_train.values #dataframe转换为array
values = x_train.astype('float32') #定义数据类型

data = preprocessing.scale(values) 
df=pd.DataFrame(data) #将array还原为dataframe

df.columns=data_features_1.columns
x_train = df

# %%
values = x_test.values #dataframe转换为array
values = x_test.astype('float32') #定义数据类型

data = preprocessing.scale(values) 
df=pd.DataFrame(data) #将array还原为dataframe

df.columns=data_features_1.columns
x_test = df

# %%
## 从sklearn中导入逻辑回归模型
from sklearn.linear_model import LogisticRegression

# %%
## 定义逻辑回归模型 
clf = LogisticRegression(random_state=0, solver='lbfgs')

# %%
# 在训练集上训练逻辑回归模型
clf.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
## 查看其对应的w
print('the weight of Logistic Regression:',clf.coef_)

## 查看其对应的w0
print('the intercept(w0) of Logistic Regression:',clf.intercept_)
# Out:
# the weight of Logistic Regression: [[-0.1008713  -0.35769733 -0.27966398 -0.240689    0.07158118  0.16937142
#   -0.49342137  0.37548666 -0.07224634 -0.09458091]]
# the intercept(w0) of Logistic Regression: [-1.8261108]

# %%
## 在训练集和测试集上分布利用训练好的模型进行预测
train_predict = clf.predict(x_train)
test_predict = clf.predict(x_test)
# Out:
# C:\Users\24670\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:291: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   indices = (scores > 0).astype(np.int)
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
from sklearn import metrics

## 
print('训练集')
print('准确率：',accuracy_score(y_train,train_predict))
print('精确率：',precision_score(y_train,train_predict))
print('召回率：',recall_score(y_train,train_predict))
print('测试集')
print('准确率：',accuracy_score(y_test, test_predict))
print('精确率：',precision_score(y_test, test_predict))
print('召回率：',recall_score(y_test, test_predict))

## 查看混淆矩阵 (预测值和真实值的各类情况统计矩阵)
confusion_matrix_result = metrics.confusion_matrix(test_predict,y_test)
print('The confusion matrix result:\n',confusion_matrix_result)

# 利用热力图对于结果进行可视化
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_result, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
# 训练集
# 准确率： 0.8429752066115702
# 精确率： 0.6
# 召回率： 0.03896103896103896
# 测试集
# 准确率： 0.8016528925619835
# 精确率： 1.0
# 召回率： 0.07692307692307693
# The confusion matrix result:
#  [[95 24]
#  [ 0  2]]

# %%
# ROC曲线和AUC
test_predict_proba = clf.predict_proba(x_test) [::, 1]
fpr, tpr, thresholds = roc_curve(y_test, test_predict_proba)
auc = roc_auc_score(y_test, test_predict_proba)
plt.figure(figsize=(5, 3), dpi=100)
plt.plot(fpr, tpr, label="AUC={:.2f}" .format(auc))
plt.legend(loc=4, fontsize=10)
plt.title('ROC and AUC',fontsize=20)
plt.xlabel('FPR',fontsize=14)
plt.ylabel('TPR',fontsize=14)
plt.show()
